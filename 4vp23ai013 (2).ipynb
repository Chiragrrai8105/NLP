# %% [markdown]
# ### DEMO

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
text="Natural Language Processing is amazing!"
tokens=word_tokenize(text)
print(tokens)
# Out:
# Requirement already satisfied: nltk in ./anaconda3/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: regex>=2021.8.3 in ./anaconda3/lib/python3.10/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.10/site-packages (from nltk) (1.1.1)
# Requirement already satisfied: click in ./anaconda3/lib/python3.10/site-packages (from nltk) (8.0.4)
# ['Natural', 'Language', 'Processing', 'is', 'amazing', '!']
# [nltk_data] Downloading package punkt_tab to /home/ds-lab/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
import spacy
nlp=spacy.load("en_core_web_sm")
text="Elon musk founded Spacex in 2002."
doc=nlp(text)
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Requirement already satisfied: spacy in ./anaconda3/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: numpy>=1.19.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./anaconda3/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./anaconda3/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./anaconda3/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./anaconda3/lib/python3.10/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./anaconda3/lib/python3.10/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./anaconda3/lib/python3.10/site-packages (from spacy) (2.10.3)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in ./anaconda3/lib/python3.10/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (24.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./anaconda3/lib/python3.10/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: language-data>=1.2 in ./anaconda3/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: pydantic-core==2.27.1 in ./anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./anaconda3/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in ./anaconda3/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./anaconda3/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./anaconda3/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./anaconda3/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Traceback (most recent call last):
#   File "/home/ds-lab/anaconda3/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/home/ds-lab/anaconda3/lib/python3.10/runpy.py", line 146, in _get_module_details
#     return _get_module_details(pkg_main_name, error)
#   File "/home/ds-lab/anaconda3/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/spacy/__init__.py", line 6, in <module>
#     from .errors import setup_default_warnings
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/spacy/errors.py", line 3, in <module>
#     from .compat import Literal
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/spacy/compat.py", line 4, in <module>
#     from thinc.util import copy_array
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/thinc/__init__.py", line 5, in <module>
#     from .config import registry
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/thinc/config.py", line 5, in <module>
#     from .types import Decorator
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/thinc/types.py", line 25, in <module>
#     from .compat import cupy, has_cupy
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/thinc/compat.py", line 99, in <module>
#     import h5py
#   File "/home/ds-lab/anaconda3/lib/python3.10/site-packages/h5py/__init__.py", line 25, in <module>
#     from . import _errors
#   File "h5py/_errors.pyx", line 1, in init h5py._errors
# AttributeError: module 'numpy' has no attribute 'dtype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 get_ipython().system('pip install spacy')
#       2 get_ipython().system('python -m spacy download en_core_web_sm')
# ----> 3 import spacy
#       4 nlp=spacy.load("en_core_web_sm")
#       5 text="Elon musk founded Spacex in 2002."
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/compat.py:4
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 4 from thinc.util import copy_array
#       6 try:
#       7     import cPickle as pickle
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       7 # fmt: off
#       8 __all__ = [
#       9     "registry",
#      10     "__version__",
#      11 ]
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/config.py:5
#       2 import confection
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
# ----> 5 from .types import Decorator
#       8 class registry(confection.registry):
#       9     # fmt: off
#      10     optimizers: Decorator = catalogue.create("thinc", "optimizers", entry_points=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/types.py:25
#       4 from typing import (
#       5     Any,
#       6     Callable,
#    (...)
#      20     overload,
#      21 )
#      23 import numpy
# ---> 25 from .compat import cupy, has_cupy
#      27 if has_cupy:
#      28     get_array_module = cupy.get_array_module
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/compat.py:99
#      95 has_mxnet = False
#      98 try:
# ---> 99     import h5py
#     100 except ImportError:  # pragma: no cover
#     101     h5py = None
#
# File ~/anaconda3/lib/python3.10/site-packages/h5py/__init__.py:25
#      19 # --- Library setup -----------------------------------------------------------
#      20
#      21 # When importing from the root of the unpacked tarball or git checkout,
#      22 # Python sees the "h5py" source directory and tries to load it, which fails.
#      23 # We tried working around this by using "package_dir" but that breaks Cython.
#      24 try:
# ---> 25     from . import _errors
#      26 except ImportError:
#      27     import os.path as _op
#
# File h5py/_errors.pyx:1, in init h5py._errors()
#
# AttributeError: module 'numpy' has no attribute 'dtype'

# %%
# !pip install textblob
from textblob import TextBlob
text="I love python.It is so powerfull"
blob=TextBlob(text)
print(blob.sentiment)
# Out:
# Requirement already satisfied: textblob in ./anaconda3/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in ./anaconda3/lib/python3.10/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: click in ./anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in ./anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (2022.7.9)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.10/site-packages (from nltk>=3.9->textblob) (1.1.1)
# Sentiment(polarity=0.5, subjectivity=0.6)

# %%
# !pip install transformers
from transformers import pipeline
generator=pipeline("text_generation")
print(generator("Artificial Intelligence is",max_length=30))

# %% [markdown]
# ### EXP 1

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
nltk.download('punkt')
nltk.download('stopwords')
def preprocess_text(text):
    tokens = word_tokenize(text)
    print("Tokenized words:", tokens)
    filtered_tokens = [word for word in tokens if word.isalnum()]
    print("Filtered Tokens:", filtered_tokens)
    validated_tokens = [word for word in filtered_tokens if re.match("^[A-Za-z]+$", word)]
    print("Validated Tokens:", validated_tokens)
    stop_words = set(stopwords.words('english'))
    tokens_without_stopwords = [word for word in validated_tokens if word.lower() not in stop_words]
    print("Tokens after stop word removal:", tokens_without_stopwords)
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(word) for word in tokens_without_stopwords]
    print("Stemmed tokens:", stemmed_tokens)
    return stemmed_tokens
text = "Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence!"
preprocessed_text = preprocess_text(text)
# Out:
# Requirement already satisfied: nltk in ./anaconda3/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in ./anaconda3/lib/python3.10/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in ./anaconda3/lib/python3.10/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.10/site-packages (from nltk) (1.1.1)
# [nltk_data] Downloading package punkt to /home/ds-lab/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /home/ds-lab/nltk_data...
# Tokenized words: ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '!']
# Filtered Tokens: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence']
# Validated Tokens: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence']
# Tokens after stop word removal: ['Natural', 'Language', 'Processing', 'NLP', 'fascinating', 'field', 'Artificial', 'Intelligence']
# Stemmed tokens: ['natur', 'languag', 'process', 'nlp', 'fascin', 'field', 'artifici', 'intellig']
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install langdetect
from langdetect import detect
text="हैलो, क्या हाल हैं"
lang=detect(text)
print(f"the language used is: {lang}")
# Out:
# Requirement already satisfied: langdetect in ./anaconda3/lib/python3.10/site-packages (1.0.9)
# Requirement already satisfied: six in ./anaconda3/lib/python3.10/site-packages (from langdetect) (1.16.0)
# the language used is: hi

# %% [markdown]
# ### EXP 2

# %%
import nltk
from nltk import word_tokenize,ngrams
from collections import Counter
import math
nltk.download('punkt_tab')
def generate_ngrams(text,n):
    tokens = word_tokenize(text.lower())
    return list(ngrams(tokens,n))
def calculate_ngram_probabilities(ngrams_list):
    ngram_counts = Counter(ngrams_list)
    total_ngrams = sum(ngram_counts.values())
    probabilities = {ngram: count / total_ngrams for ngram, count in ngram_counts.items()}
    return probabilities
# Out:
# [nltk_data] Downloading package punkt_tab to /home/ds-lab/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# !pip install nltk
import nltk
from nltk import word_tokenize,ngrams
from collections import Counter
import math 
nltk.download('punkt_tab')



def generate_ngrams(text,n):
    tokens=word_tokenize(text.lower())
    return list(ngrams(tokens,n))
def calculate_ngram_probabilities(ngrams_list):
    ngram_counts=Counter(ngrams_list)
    total_ngrams=sum(ngram_counts.values())
    probabilities={ngram:count / total_ngrams for ngram, count in ngram_counts.items()}
    return probabilities



sentences=["i love programming.","Programming is fun.","i love coding and programming."]
text=" ".join(sentences)
unigrams=generate_ngrams(text,1)
bigrams=generate_ngrams(text,2)
trigrams=generate_ngrams(text,3)
unigram_prob=calculate_ngram_probabilities(unigrams)
bigram_prob=calculate_ngram_probabilities(bigrams)
trigram_prob=calculate_ngram_probabilities(trigrams)



for unigram,prob in unigram_prob.items():
    print("\nUnigram Probabilities:")
    print(f"{unigram}:{prob:.4f}")
for bigram,prob in bigram_prob.items():
    print("\nbigram Probabilities:")
    print(f"{bigram}:{prob:.4f}")
for trigram,prob in trigram_prob.items():
    print("\ntrigram Probabilities:")
    print(f"{trigram}:{prob:.4f}")



test_sentence="i love programming"
def compute_total_probability(test_sentence,bigram_prob,trigram_prob):
    test_words=nltk.word_tokenize(test_sentence.lower())

    bigram=1
    for i in range(1,len(test_words)):
        bigrams=(test_words[i-1],test_words[i])
        if bigrams in bigram_prob:
            bigram *=bigram_prob[bigrams]
        else:
            bigram*=1e-10

    trigram=1
    for i in range(2,len(test_words)):
        trigrams=(test_words[i-2],test_words[i-1],test_words[i])
        if trigrams in trigram_prob:
            trigram *=trigram_prob[trigrams]
        else:
            trigram*=1e-10
    return bigram,trigram

bigram_prob,trigram_prob= compute_total_probability(test_sentence,bigram_prob,trigram_prob)
print(f"Total Probability(Bigram) for '{test_sentence}':{bigram_prob:.10f}")
print(f"Total Probability(trigram) for '{test_sentence}':{trigram_prob:.10f}")
# Out:
# Requirement already satisfied: nltk in ./anaconda3/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.10/site-packages (from nltk) (1.1.1)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: regex>=2021.8.3 in ./anaconda3/lib/python3.10/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: click in ./anaconda3/lib/python3.10/site-packages (from nltk) (8.0.4)
#
# Unigram Probabilities:
# ('i',):0.1429
#
# Unigram Probabilities:
# ('love',):0.1429
#
# Unigram Probabilities:
# ('programming',):0.2143
#
# Unigram Probabilities:
# ('.',):0.2143
#
# Unigram Probabilities:
# ('is',):0.0714
#
# Unigram Probabilities:
# ('fun',):0.0714
#
# Unigram Probabilities:
# ('coding',):0.0714
#
# Unigram Probabilities:
# ('and',):0.0714
#
# bigram Probabilities:
# ('i', 'love'):0.1538
#
# bigram Probabilities:
# ('love', 'programming'):0.0769
#
# bigram Probabilities:
# ('programming', '.'):0.1538
#
# bigram Probabilities:
# ('.', 'programming'):0.0769
#
# bigram Probabilities:
# ('programming', 'is'):0.0769
#
# bigram Probabilities:
# ('is', 'fun'):0.0769
#
# bigram Probabilities:
# ('fun', '.'):0.0769
#
# bigram Probabilities:
# ('.', 'i'):0.0769
#
# bigram Probabilities:
# ('love', 'coding'):0.0769
#
# bigram Probabilities:
# ('coding', 'and'):0.0769
#
# bigram Probabilities:
# ('and', 'programming'):0.0769
#
# trigram Probabilities:
# ('i', 'love', 'programming'):0.0833
#
# trigram Probabilities:
# ('love', 'programming', '.'):0.0833
#
# trigram Probabilities:
# ('programming', '.', 'programming'):0.0833
#
# trigram Probabilities:
# ('.', 'programming', 'is'):0.0833
#
# trigram Probabilities:
# ('programming', 'is', 'fun'):0.0833
#
# trigram Probabilities:
# ('is', 'fun', '.'):0.0833
#
# trigram Probabilities:
# ('fun', '.', 'i'):0.0833
#
# trigram Probabilities:
# ('.', 'i', 'love'):0.0833
#
# trigram Probabilities:
# ('i', 'love', 'coding'):0.0833
#
# trigram Probabilities:
# ('love', 'coding', 'and'):0.0833
#
# trigram Probabilities:
# ('coding', 'and', 'programming'):0.0833
#
# trigram Probabilities:
# ('and', 'programming', '.'):0.0833
# Total Probability(Bigram) for 'i love programming':0.0118343195
# Total Probability(trigram) for 'i love programming':0.0833333333
# [nltk_data] Downloading package punkt_tab to /home/ds-lab/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ### EXP 3

# %%
def med(str1,str2):
    m,n=len(str1),len(str2)
    dp=[[0 for _ in range(n+1)] for _ in range(m+1)]
    for i in range(m+1):
        dp[i][0]=i
    for j in range(n+1):
        dp[0][j]=j
    for i in range(1,m+1):
        for j in range(1,n+1):
            if str1[i-1]==str2[j-1]:
                dp[i][j]=dp[i-1][j-1]
            else:
                dp[i][j]=1+min(dp[i-1][j],dp[i][j-1],dp[i-1][j-1])
    return dp[m][n]
test_cases=[("kitten","sitting"),
            ("flaw","lawn"),
            ("intention","execution"),
            ("apple","aple"),
            ("recieve","receive")]
for str1, str2 in test_cases:
    print(f"MED between '{str1}' and '{str2}': {med(str1, str2)}")
# Out:
# MED between 'kitten' and 'sitting': 3
# MED between 'flaw' and 'lawn': 2
# MED between 'intention' and 'execution': 5
# MED between 'apple' and 'aple': 1
# MED between 'recieve' and 'receive': 2

# %% [markdown]
# ### EXP 4

# %% [markdown]
# #### Top down parsing

# %%
class TDP:
    def __init__ (self,input_String):
        self.input=input_string
        self.index=0
    def match(self,char):
        if self.index<len(self.input)and self.input[self.index]==char:
             self.index+=1
             return True
        return False
    def S(self):
        if self.match('a') and self.A() and self.B():
            return True
        return False
    def A(self):
        if self.match('b'):
            return True
        return True
    def B(self):
        return self.match('c')
    def parse(self):
        return self.S() and self.index==len(self.input)
input_string="abc"
td_parser=TDP(input_string)
print("Top-Down parsing Result:",td_parser.parse())
# Out:
# Top-Down parsing Result: True

# %% [markdown]
# #### Bottom up parsing

# %%
class BUP:
    def __init__(self, input_string):
        self.input = list(input_string)
        self.stack = []
    def shift(self):
        if self.input:
            self.stack.append(self.input.pop(0))
    def reduce(self):
        if ''.join(self.stack[-2:]) == 'bc':
            self.stack[-2:] = ['A']
        elif ''.join(self.stack[-2:]) == 'aA':
            self.stack[-2:] = ['S']
        elif ''.join(self.stack) == 'S':
            return True
        return False
    def parse(self):
        while self.input or len(self.stack) > 1:
            self.shift()
            while self.reduce():
                pass
        return self.stack == ['S']
input_string = "abc"
bu_parser = BUP(input_string)
print("Bottom-Up Parsing Result:", bu_parser.parse())
# Out:
# Bottom-Up Parsing Result: True

# %% [markdown]
# ### EXP 5

# %%
from collections import defaultdict
import math
data = [
    ("fun, couple, cry, cry, comedy", "Comedy"),
    ("fast, furious, shoot, smile", "Walk"),
    ("couple, fly, fast, fun, fun, comedy", "Comedy"),
    ("furious, shoot, shoot, fun, action", "Walk"),
    ("fly, fast, shoot, love, action", "Walk")
]
test_doc = "fast, couple, shoot, fly"
def tokenize(text):
    return text.lower().split(", ")
def train_naive_bayes(data):
    word_counts = defaultdict(lambda: defaultdict(int)) 
    class_counts = defaultdict(int)
    vocab = set()
    for text, label in data:
        class_counts[label] += 1
        for word in tokenize(text):
            word_counts[label][word] += 1
            vocab.add(word)
    return word_counts, class_counts, len(vocab)
def classify(text, word_counts, class_counts, vocab_size):
    priors = {c: math.log(class_counts[c] / sum(class_counts.values())) for c in class_counts}
    posteriors = {
        c: priors[c] + sum(
            math.log((word_counts[c][w] + 1) /
            (sum(word_counts[c].values()) + vocab_size))
            for w in tokenize(text)
        )
        for c in class_counts
    }
    return max(posteriors, key=posteriors.get)
word_counts, class_counts, vocab_size = train_naive_bayes(data)
predicted_class = classify(test_doc, word_counts, class_counts, vocab_size)
print(f"Test Doc: {test_doc}")
print(f"Predicted Class: {predicted_class}")
# Out:
# Test Doc: fast, couple, shoot, fly
# Predicted Class: Walk

# %% [markdown]
# ### EXP 6

# %%
import nltk
from nltk.corpus import brown,inaugural,reuters,udhr
from nltk import FreqDist,ConditionalFreqDist
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag,UnigramTagger
from nltk.probability import FreqDist
from nltk.corpus import PlaintextCorpusReader

# %%
nltk.download('brown')
nltk.download('inaugural')
nltk.download('reuters')
nltk.download('udhr')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package brown to /home/ds-lab/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package inaugural to /home/ds-lab/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package reuters to /home/ds-lab/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package udhr to /home/ds-lab/nltk_data...
# [nltk_data]   Package udhr is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ds-lab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ds-lab/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def explore_corpora():
    print("\n Brown Corpus categories:",brown.categories())
    print("First 10 words in Inaugural corpus:",inaugural.words()[:10])
    print("First 10 words in Reuters corpus:",reuters.words()[:10])
    print("First 10 words in UDHR corpus(English):",udhr.words('English-Latin1')[:10])
    return explore_corpora
explore_corpora()
# Out:
#  Brown Corpus categories: ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
# First 10 words in Inaugural corpus: ['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'of', 'the', 'House']
# First 10 words in Reuters corpus: ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', '.', 'S', '.-', 'JAPAN']
# First 10 words in UDHR corpus(English): ['Universal', 'Declaration', 'of', 'Human', 'Rights', 'Preamble', 'Whereas', 'recognition', 'of', 'the']
# <function __main__.explore_corpora()>

# %%
import os
def create_custom_corpus():
    corpus_root = '.' 
    if not any(f.endswith('.txt') for f in os.listdir(corpus_root)):
        with open("file.txt", "w") as f:
            f.write("Natural Language Processing is a subfield of artificial intelligence.")
    wordlists = PlaintextCorpusReader(corpus_root, '.*\.txt')
    print("\nFiles found in current folder:", wordlists.fileids())
    print("First 20 words:", wordlists.words()[:20])
create_custom_corpus()
# Out:
# Files found in current folder: ['.ipynb_checkpoints/EXP6-checkpoint.txt', 'EXP6.txt']
# First 20 words: ['Artificial', 'intelligence', '(', 'AI', ')', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'by', 'computer', 'systems', 'to', 'perform', 'tasks', 'like', 'learning', ',']

# %%
def conditional_frequency():
    cfd = ConditionalFreqDist(
    (genre, word.lower())
    for genre in brown.categories()
    for word in brown.words(categories=genre)
    )
    print("\nMost common words in 'news' category:", cfd['news'].most_common(10))
    return conditional_frequency
conditional_frequency()
# Out:
# Most common words in 'news' category: [('the', 6386), (',', 5188), ('.', 4030), ('of', 2861), ('and', 2186), ('to', 2144), ('a', 2130), ('in', 2020), ('for', 969), ('that', 829)]
# <function __main__.conditional_frequency()>

# %%
def frequent_noun_tags():
    tagged_words = brown.tagged_words()
    noun_tags = [word for word, tag in tagged_words if tag.startswith('NN')]
    fdist = FreqDist(noun_tags)
    print("\nMost Frequent Nouns:", fdist.most_common(10))
    return frequent_noun_tags
frequent_noun_tags()
# Out:
# Most Frequent Nouns: [('time', 1555), ('man', 1148), ('Af', 994), ('years', 942), ('way', 883), ('people', 809), ('men', 736), ('world', 684), ('life', 676), ('year', 647)]
# <function __main__.frequent_noun_tags()>

# %%
def word_properties(): 
    word_dict = {"AI": "Artificial Intelligence", "NLP": "Natural Language Processing", "ML": 
    "Machine Learning"} 
    print("\nWord Properties:", word_dict["NLP"])
    return word_properties
word_properties()
# Out:
# Word Properties: Natural Language Processing
# <function __main__.word_properties()>

# %%
def unigram_tagger_demo():
    tagged_sents = brown.tagged_sents(categories='news')
    train_data = tagged_sents[:4000]
    test_data = tagged_sents[4000:]
    unigram_tagger = UnigramTagger(train_data)
    accuracy = unigram_tagger.evaluate(test_data)
    print("\nUnigram Tagger Accuracy:", round(accuracy, 4))
    return unigram_tagger
unigram_tagger_demo()
# Out:
# Unigram Tagger Accuracy: 0.8111
# /tmp/ipykernel_4380/408729081.py:6: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = unigram_tagger.evaluate(test_data)
# <UnigramTagger: size=13252>

# %%
def segment_text(text, corpus_words):
    words = []
    while text:
        for i in range(len(text), 0, -1):
            if text[:i] in corpus_words:
                words.append(text[:i])
                text = text[i:]
                break
        else:
            words.append(text[0])
            text = text[1:]
    return words

# %%
def word_segmentation():
    corpus_words = set(w.lower() for w in brown.words())
    text = "thisisatextwithoutspaces"
    segmented_words = segment_text(text, corpus_words)
    print("\nSegmented Words:", segmented_words)
word_segmentation()
# Out:
# Segmented Words: ['this', 'is', 'ate', 'x', 't', 'without', 'spaces']

# %% [markdown]
# ### EXP 7

# %%
import nltk
from nltk.corpus import wordnet
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/ds-lab/nltk_data...
# True

# %%
def get_syn_an(word):
    synonyms=set()
    antonyms=set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
    return synonyms,antonyms

# %%
word="active"
synonyms,antonyms=get_syn_an(word)
print(f"word:{word}")
print("Synonyms:",synonyms)
print("Antonyms:",antonyms)
# Out:
# word:active
# Synonyms: {'combat-ready', 'participating', 'alive', 'active', 'fighting', 'active_voice', 'active_agent', 'dynamic'}
# Antonyms: {'stative', 'dormant', 'quiet', 'passive_voice', 'extinct', 'passive', 'inactive'}

# %% [markdown]
# ### EXP 8

# %%
# !pip install datasets
from datasets import load_dataset
from transformers import AutoTokenizer,AutoModelForSeq2SeqLM
# Out:
# Requirement already satisfied: datasets in /home/ds-lab/anaconda3/lib/python3.10/site-packages (3.5.1)
# Requirement already satisfied: filelock in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (3.9.0)
# Requirement already satisfied: xxhash in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: multiprocess<0.70.17 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2025.3.0,>=2023.1.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (2024.12.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (19.0.1)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (1.24.4)
# Requirement already satisfied: tqdm>=4.66.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: packaging in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (24.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: aiohttp in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (3.11.18)
# Requirement already satisfied: requests>=2.32.2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in /home/ds-lab/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
dataset=load_dataset("cfilt/iitb-english-hindi")

# %%
tokenizer=AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
# Out:
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]

# %%
model=AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
# Out:
# /home/ds-lab/anaconda3/lib/python3.10/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]

# %%
article=dataset['validation'][2]['translation']['en']
inputs=tokenizer(article,return_tensors="pt")
translated_tokens=model.generate(**inputs,max_length=256)
translated_text=tokenizer.decode(translated_tokens[0],skip_special_tokens=True)
print(translated_text)
# Out:
# एमएनएपी शिक्षकों के राष्ट्रपति, राजस्वीवर ने इस पुरस्कार को पेश करने के द्वारा स्कूल की प्रतिष्ठा की.

# %% [markdown]
# ### EXP 1

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

def preprocess_text(text):
    tokens = word_tokenize(text)
    print("Tokenized words:", tokens)

    tokens = list(filter(str.isalpha, tokens))  # built-in filter
    print("Filtered Tokens:", tokens)

    print("Validated Tokens:", tokens)

    tokens = [w for w in tokens if w.lower() not in stop_words]
    print("Tokens after stop word removal:", tokens)

    tokens = list(map(stemmer.stem, tokens))  # built-in map
    print("Stemmed tokens:", tokens)

    return tokens

# Example
text = "Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence!"
preprocessed_text = preprocess_text(text)
# Out:
# Tokenized words: ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '!']
# Filtered Tokens: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence']
# Validated Tokens: ['Natural', 'Language', 'Processing', 'NLP', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence']
# Tokens after stop word removal: ['Natural', 'Language', 'Processing', 'NLP', 'fascinating', 'field', 'Artificial', 'Intelligence']
# Stemmed tokens: ['natur', 'languag', 'process', 'nlp', 'fascin', 'field', 'artifici', 'intellig']
# [nltk_data] Downloading package punkt to /home/ds-lab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/ds-lab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
